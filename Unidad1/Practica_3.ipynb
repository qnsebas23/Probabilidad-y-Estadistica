# %% [markdown]
# <a href="https://colab.research.google.com/github/qnsebas23/Probabilidad-y-Estadistica/blob/main/Unidad1/Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Probabilidad y estadistica**
#
# ## Unidad 1
#
# ### *Practica 3. Tabla de frecuencias y regla de Sturges..*
#
# ## Facilitador: *Dr. José Gabriel Rodríguez Rivas*
#
# ### ALumno: Sebastian Quiñones Nevarez

# %%
import random
edades = []

for i in range(100):
  numero_aleatorio = random.randint( 18, 70)
  edades.append(numero_aleatorio)

print(edades)
# Out:
# [20, 23, 40, 37, 61, 56, 44, 34, 47, 60, 65, 19, 39, 38, 30, 48, 31, 44, 60, 49, 19, 37, 23, 69, 51, 18, 32, 48, 66, 26, 30, 44, 20, 53, 53, 22, 20, 35, 64, 49, 42, 58, 35, 39, 31, 53, 67, 57, 54, 18, 69, 29, 66, 70, 46, 40, 61, 65, 23, 35, 61, 44, 37, 56, 37, 65, 44, 59, 34, 66, 55, 32, 19, 24, 25, 42, 35, 56, 36, 29, 36, 60, 26, 35, 55, 30, 35, 64, 36, 56, 57, 20, 30, 54, 28, 45, 47, 60, 66, 68]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    20
# 1    23
# 2    40
# 3    37
# 4    61

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

print("Tabla de Distribución de Frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 23    18           2
# 10    19           3
# 3     20           4
# 32    22           1
# 9     23           3
# 38    24           1
# 40    25           1
# 20    26           2
# 41    28           1
# 25    29           2
# 6     30           4
# 27    31           2
# 21    32           2
# 15    34           2
# 0     35           6
# 12    36           3
# 7     37           4
# 31    38           1
# 19    39           2
# 14    40           2
# 26    42           2
# 1     44           5
# 42    45           1
# 36    46           1
# 16    47           2
# 18    48           2
# 22    49           2
# 33    51           1
# 13    53           3
# 29    54           2
# 28    55           2
# 2     56           4
# 30    57           2
# 35    58           1
# 39    59           1
# 4     60           4
# 11    61           3
# 24    64           2
# 8     65           3
# 5     66           4
# 34    67           1
# 43    68           1
# 17    69           2
# 37    70           1

# %% [markdown]
# #Calcular frecuencia relativa

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 23    18           2           0.02
# 10    19           3           0.03
# 3     20           4           0.04
# 32    22           1           0.01
# 9     23           3           0.03
# 38    24           1           0.01
# 40    25           1           0.01
# 20    26           2           0.02
# 41    28           1           0.01
# 25    29           2           0.02
# 6     30           4           0.04
# 27    31           2           0.02
# 21    32           2           0.02
# 15    34           2           0.02
# 0     35           6           0.06
# 12    36           3           0.03
# 7     37           4           0.04
# 31    38           1           0.01
# 19    39           2           0.02
# 14    40           2           0.02
# 26    42           2           0.02
# 1     44           5           0.05
# 42    45           1           0.01
# 36    46           1           0.01
# 16    47           2           0.02
# 18    48           2           0.02
# 22    49           2           0.02
# 33    51           1           0.01
# 13    53           3           0.03
# 29    54           2           0.02
# 28    55           2           0.02
# 2     56           4           0.04
# 30    57           2           0.02
# 35    58           1           0.01
# 39    59           1           0.01
# 4     60           4           0.04
# 11    61           3           0.03
# 24    64           2           0.02
# 8     65           3           0.03
# 5     66           4           0.04
# 34    67           1           0.01
# 43    68           1           0.01
# 17    69           2           0.02
# 37    70           1           0.01

# %% [markdown]
# #Calcular la frecuencia porcentual

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 23    18           2           0.02              2.0
# 10    19           3           0.03              3.0
# 3     20           4           0.04              4.0
# 32    22           1           0.01              1.0
# 9     23           3           0.03              3.0
# 38    24           1           0.01              1.0
# 40    25           1           0.01              1.0
# 20    26           2           0.02              2.0
# 41    28           1           0.01              1.0
# 25    29           2           0.02              2.0
# 6     30           4           0.04              4.0
# 27    31           2           0.02              2.0
# 21    32           2           0.02              2.0
# 15    34           2           0.02              2.0
# 0     35           6           0.06              6.0
# 12    36           3           0.03              3.0
# 7     37           4           0.04              4.0
# 31    38           1           0.01              1.0
# 19    39           2           0.02              2.0
# 14    40           2           0.02              2.0
# 26    42           2           0.02              2.0
# 1     44           5           0.05              5.0
# 42    45           1           0.01              1.0
# 36    46           1           0.01              1.0
# 16    47           2           0.02              2.0
# 18    48           2           0.02              2.0
# 22    49           2           0.02              2.0
# 33    51           1           0.01              1.0
# 13    53           3           0.03              3.0
# 29    54           2           0.02              2.0
# 28    55           2           0.02              2.0
# 2     56           4           0.04              4.0
# 30    57           2           0.02              2.0
# 35    58           1           0.01              1.0
# 39    59           1           0.01              1.0
# 4     60           4           0.04              4.0
# 11    61           3           0.03              3.0
# 24    64           2           0.02              2.0
# 8     65           3           0.03              3.0
# 5     66           4           0.04              4.0
# 34    67           1           0.01              1.0
# 43    68           1           0.01              1.0
# 17    69           2           0.02              2.0
# 37    70           1           0.01              1.0

# %% [markdown]
# #Calcular la frecuencia acumulada

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 23    18           2           0.02              2.0               2
# 10    19           3           0.03              3.0               5
# 3     20           4           0.04              4.0               9
# 32    22           1           0.01              1.0              10
# 9     23           3           0.03              3.0              13
# 38    24           1           0.01              1.0              14
# 40    25           1           0.01              1.0              15
# 20    26           2           0.02              2.0              17
# 41    28           1           0.01              1.0              18
# 25    29           2           0.02              2.0              20
# 6     30           4           0.04              4.0              24
# 27    31           2           0.02              2.0              26
# 21    32           2           0.02              2.0              28
# 15    34           2           0.02              2.0              30
# 0     35           6           0.06              6.0              36
# 12    36           3           0.03              3.0              39
# 7     37           4           0.04              4.0              43
# 31    38           1           0.01              1.0              44
# 19    39           2           0.02              2.0              46
# 14    40           2           0.02              2.0              48
# 26    42           2           0.02              2.0              50
# 1     44           5           0.05              5.0              55
# 42    45           1           0.01              1.0              56
# 36    46           1           0.01              1.0              57
# 16    47           2           0.02              2.0              59
# 18    48           2           0.02              2.0              61
# 22    49           2           0.02              2.0              63
# 33    51           1           0.01              1.0              64
# 13    53           3           0.03              3.0              67
# 29    54           2           0.02              2.0              69
# 28    55           2           0.02              2.0              71
# 2     56           4           0.04              4.0              75
# 30    57           2           0.02              2.0              77
# 35    58           1           0.01              1.0              78
# 39    59           1           0.01              1.0              79
# 4     60           4           0.04              4.0              83
# 11    61           3           0.03              3.0              86
# 24    64           2           0.02              2.0              88
# 8     65           3           0.03              3.0              91
# 5     66           4           0.04              4.0              95
# 34    67           1           0.01              1.0              96
# 43    68           1           0.01              1.0              97
# 17    69           2           0.02              2.0              99
# 37    70           1           0.01              1.0             100

# %% [markdown]
# #Regla de sturges
#
# sirve para calcular el número de clases o intervalos idóneo en los que se debe dividir un conjunto de datos.
#
# 𝑐 = 1 + log2(𝑛)
#
# donde 𝑛 es el tamaño de la muestra

# %%
import math

# %%
print(edades)
# Out:
# [20, 23, 40, 37, 61, 56, 44, 34, 47, 60, 65, 19, 39, 38, 30, 48, 31, 44, 60, 49, 19, 37, 23, 69, 51, 18, 32, 48, 66, 26, 30, 44, 20, 53, 53, 22, 20, 35, 64, 49, 42, 58, 35, 39, 31, 53, 67, 57, 54, 18, 69, 29, 66, 70, 46, 40, 61, 65, 23, 35, 61, 44, 37, 56, 37, 65, 44, 59, 34, 66, 55, 32, 19, 24, 25, 42, 35, 56, 36, 29, 36, 60, 26, 35, 55, 30, 35, 64, 36, 56, 57, 20, 30, 54, 28, 45, 47, 60, 66, 68]

# %%
df = pd.DataFrame({'Edad' : edades})
df
# Out:
#     Edad
# 0     20
# 1     23
# 2     40
# 3     37
# 4     61
# ..   ...
# 95    45
# 96    47
# 97    60
# 98    66
# 99    68
#
# [100 rows x 1 columns]

# %%
n = len(edades)
K = int( 1 + math.log2(n))
print("Valor de n = ", n, "\nNúmero de intervalos =", K)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
tabla_frecuencia = pd.cut ( df['Edad'], bins = K, include_lowest = True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (32.857, 40.286]    20
# 1  (17.947, 25.429]    15
# 2  (55.143, 62.571]    15
# 3    (62.571, 70.0]    14
# 4  (25.429, 32.857]    13
# 5  (47.714, 55.143]    12
# 6  (40.286, 47.714]    11

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 1  (17.947, 25.429]    15
# 4  (25.429, 32.857]    13
# 0  (32.857, 40.286]    20
# 6  (40.286, 47.714]    11
# 5  (47.714, 55.143]    12
# 2  (55.143, 62.571]    15
# 3    (62.571, 70.0]    14

# %%
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'] .cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 1  (17.947, 25.429]    15      0.15       15.0       15         0.15
# 4  (25.429, 32.857]    13      0.13       13.0       28         0.28
# 0  (32.857, 40.286]    20      0.20       20.0       48         0.48
# 6  (40.286, 47.714]    11      0.11       11.0       59         0.59
# 5  (47.714, 55.143]    12      0.12       12.0       71         0.71
# 2  (55.143, 62.571]    15      0.15       15.0       86         0.86
# 3    (62.571, 70.0]    14      0.14       14.0      100         1.00
#
#    Frec Porc Ac
# 1          15.0
# 4          28.0
# 0          48.0
# 6          59.0
# 5          71.0
# 2          86.0
# 3         100.0

# %%
import matplotlib.pyplot as plt

plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion matplpotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion matplpotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
