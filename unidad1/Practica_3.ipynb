# %% [markdown]
# <a href="https://colab.research.google.com/github/qnsebas23/Probabilidad-y-Estadistica/blob/main/unidad1/Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Probabilidad y estadistica**
#
# ## Unidad 1
#
# ### *Practica 3. Tabla de frecuencias y regla de Sturges..*
#
# ## Facilitador: *Dr. José Gabriel Rodríguez Rivas*
#
# ### ALumno: Sebastian Quiñones Nevarez

# %%
import random
edades = []

for i in range(100):
  numero_aleatorio = random.randint( 18, 70)
  edades.append(numero_aleatorio)

print(edades)
# Out:
# [28, 66, 18, 64, 66, 45, 24, 51, 36, 61, 50, 27, 58, 22, 69, 54, 62, 34, 66, 54, 49, 66, 24, 34, 64, 26, 69, 29, 63, 47, 22, 58, 68, 48, 36, 54, 28, 51, 33, 39, 28, 56, 46, 58, 39, 42, 23, 67, 20, 60, 45, 34, 68, 50, 31, 70, 36, 28, 57, 59, 50, 36, 21, 44, 29, 70, 32, 32, 44, 19, 47, 18, 44, 52, 43, 68, 41, 18, 24, 66, 37, 27, 20, 40, 54, 44, 62, 47, 53, 26, 64, 25, 42, 43, 22, 59, 70, 54, 40, 34]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    28
# 1    66
# 2    18
# 3    64
# 4    66

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

print("Tabla de Distribución de Frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 14    18           3
# 43    19           1
# 21    20           2
# 40    21           1
# 8     22           3
# 33    23           1
# 7     24           3
# 47    25           1
# 23    26           2
# 18    27           2
# 3     28           4
# 22    29           2
# 39    31           1
# 16    32           2
# 36    33           1
# 5     34           4
# 2     36           4
# 45    37           1
# 28    39           2
# 27    40           2
# 44    41           1
# 24    42           2
# 26    43           2
# 4     44           4
# 20    45           2
# 35    46           1
# 12    47           3
# 30    48           1
# 37    49           1
# 10    50           3
# 15    51           2
# 42    52           1
# 46    53           1
# 1     54           5
# 34    56           1
# 38    57           1
# 9     58           3
# 25    59           2
# 41    60           1
# 29    61           1
# 17    62           2
# 31    63           1
# 6     64           3
# 0     66           5
# 32    67           1
# 13    68           3
# 19    69           2
# 11    70           3

# %% [markdown]
# #Calcular frecuencia relativa

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 14    18           3           0.03
# 43    19           1           0.01
# 21    20           2           0.02
# 40    21           1           0.01
# 8     22           3           0.03
# 33    23           1           0.01
# 7     24           3           0.03
# 47    25           1           0.01
# 23    26           2           0.02
# 18    27           2           0.02
# 3     28           4           0.04
# 22    29           2           0.02
# 39    31           1           0.01
# 16    32           2           0.02
# 36    33           1           0.01
# 5     34           4           0.04
# 2     36           4           0.04
# 45    37           1           0.01
# 28    39           2           0.02
# 27    40           2           0.02
# 44    41           1           0.01
# 24    42           2           0.02
# 26    43           2           0.02
# 4     44           4           0.04
# 20    45           2           0.02
# 35    46           1           0.01
# 12    47           3           0.03
# 30    48           1           0.01
# 37    49           1           0.01
# 10    50           3           0.03
# 15    51           2           0.02
# 42    52           1           0.01
# 46    53           1           0.01
# 1     54           5           0.05
# 34    56           1           0.01
# 38    57           1           0.01
# 9     58           3           0.03
# 25    59           2           0.02
# 41    60           1           0.01
# 29    61           1           0.01
# 17    62           2           0.02
# 31    63           1           0.01
# 6     64           3           0.03
# 0     66           5           0.05
# 32    67           1           0.01
# 13    68           3           0.03
# 19    69           2           0.02
# 11    70           3           0.03

# %% [markdown]
# #Calcular la frecuencia porcentual

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 14    18           3           0.03              3.0
# 43    19           1           0.01              1.0
# 21    20           2           0.02              2.0
# 40    21           1           0.01              1.0
# 8     22           3           0.03              3.0
# 33    23           1           0.01              1.0
# 7     24           3           0.03              3.0
# 47    25           1           0.01              1.0
# 23    26           2           0.02              2.0
# 18    27           2           0.02              2.0
# 3     28           4           0.04              4.0
# 22    29           2           0.02              2.0
# 39    31           1           0.01              1.0
# 16    32           2           0.02              2.0
# 36    33           1           0.01              1.0
# 5     34           4           0.04              4.0
# 2     36           4           0.04              4.0
# 45    37           1           0.01              1.0
# 28    39           2           0.02              2.0
# 27    40           2           0.02              2.0
# 44    41           1           0.01              1.0
# 24    42           2           0.02              2.0
# 26    43           2           0.02              2.0
# 4     44           4           0.04              4.0
# 20    45           2           0.02              2.0
# 35    46           1           0.01              1.0
# 12    47           3           0.03              3.0
# 30    48           1           0.01              1.0
# 37    49           1           0.01              1.0
# 10    50           3           0.03              3.0
# 15    51           2           0.02              2.0
# 42    52           1           0.01              1.0
# 46    53           1           0.01              1.0
# 1     54           5           0.05              5.0
# 34    56           1           0.01              1.0
# 38    57           1           0.01              1.0
# 9     58           3           0.03              3.0
# 25    59           2           0.02              2.0
# 41    60           1           0.01              1.0
# 29    61           1           0.01              1.0
# 17    62           2           0.02              2.0
# 31    63           1           0.01              1.0
# 6     64           3           0.03              3.0
# 0     66           5           0.05              5.0
# 32    67           1           0.01              1.0
# 13    68           3           0.03              3.0
# 19    69           2           0.02              2.0
# 11    70           3           0.03              3.0

# %% [markdown]
# #Calcular la frecuencia acumulada

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 14    18           3           0.03              3.0               3
# 43    19           1           0.01              1.0               4
# 21    20           2           0.02              2.0               6
# 40    21           1           0.01              1.0               7
# 8     22           3           0.03              3.0              10
# 33    23           1           0.01              1.0              11
# 7     24           3           0.03              3.0              14
# 47    25           1           0.01              1.0              15
# 23    26           2           0.02              2.0              17
# 18    27           2           0.02              2.0              19
# 3     28           4           0.04              4.0              23
# 22    29           2           0.02              2.0              25
# 39    31           1           0.01              1.0              26
# 16    32           2           0.02              2.0              28
# 36    33           1           0.01              1.0              29
# 5     34           4           0.04              4.0              33
# 2     36           4           0.04              4.0              37
# 45    37           1           0.01              1.0              38
# 28    39           2           0.02              2.0              40
# 27    40           2           0.02              2.0              42
# 44    41           1           0.01              1.0              43
# 24    42           2           0.02              2.0              45
# 26    43           2           0.02              2.0              47
# 4     44           4           0.04              4.0              51
# 20    45           2           0.02              2.0              53
# 35    46           1           0.01              1.0              54
# 12    47           3           0.03              3.0              57
# 30    48           1           0.01              1.0              58
# 37    49           1           0.01              1.0              59
# 10    50           3           0.03              3.0              62
# 15    51           2           0.02              2.0              64
# 42    52           1           0.01              1.0              65
# 46    53           1           0.01              1.0              66
# 1     54           5           0.05              5.0              71
# 34    56           1           0.01              1.0              72
# 38    57           1           0.01              1.0              73
# 9     58           3           0.03              3.0              76
# 25    59           2           0.02              2.0              78
# 41    60           1           0.01              1.0              79
# 29    61           1           0.01              1.0              80
# 17    62           2           0.02              2.0              82
# 31    63           1           0.01              1.0              83
# 6     64           3           0.03              3.0              86
# 0     66           5           0.05              5.0              91
# 32    67           1           0.01              1.0              92
# 13    68           3           0.03              3.0              95
# 19    69           2           0.02              2.0              97
# 11    70           3           0.03              3.0             100

# %% [markdown]
# #Regla de sturges
#
# sirve para calcular el número de clases o intervalos idóneo en los que se debe dividir un conjunto de datos.
#
# 𝑐 = 1 + log2(𝑛)
#
# donde 𝑛 es el tamaño de la muestra

# %%
import math

# %%
print(edades)
# Out:
# [28, 66, 18, 64, 66, 45, 24, 51, 36, 61, 50, 27, 58, 22, 69, 54, 62, 34, 66, 54, 49, 66, 24, 34, 64, 26, 69, 29, 63, 47, 22, 58, 68, 48, 36, 54, 28, 51, 33, 39, 28, 56, 46, 58, 39, 42, 23, 67, 20, 60, 45, 34, 68, 50, 31, 70, 36, 28, 57, 59, 50, 36, 21, 44, 29, 70, 32, 32, 44, 19, 47, 18, 44, 52, 43, 68, 41, 18, 24, 66, 37, 27, 20, 40, 54, 44, 62, 47, 53, 26, 64, 25, 42, 43, 22, 59, 70, 54, 40, 34]

# %%
df = pd.DataFrame({'Edad' : edades})
df
# Out:
#     Edad
# 0     28
# 1     66
# 2     18
# 3     64
# 4     66
# ..   ...
# 95    59
# 96    70
# 97    54
# 98    40
# 99    34
#
# [100 rows x 1 columns]

# %%
n = len(edades)
K = int( 1 + math.log2(n))
print("Valor de n = ", n, "\nNúmero de intervalos =", K)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
tabla_frecuencia = pd.cut ( df['Edad'], bins = K, include_lowest = True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0    (62.571, 70.0]    18
# 1  (40.286, 47.714]    15
# 2  (17.947, 25.429]    15
# 3  (47.714, 55.143]    14
# 4  (32.857, 40.286]    14
# 5  (25.429, 32.857]    13
# 6  (55.143, 62.571]    11

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 2  (17.947, 25.429]    15
# 5  (25.429, 32.857]    13
# 4  (32.857, 40.286]    14
# 1  (40.286, 47.714]    15
# 3  (47.714, 55.143]    14
# 6  (55.143, 62.571]    11
# 0    (62.571, 70.0]    18

# %%
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'] .cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 2  (17.947, 25.429]    15      0.15       15.0       15         0.15
# 5  (25.429, 32.857]    13      0.13       13.0       28         0.28
# 4  (32.857, 40.286]    14      0.14       14.0       42         0.42
# 1  (40.286, 47.714]    15      0.15       15.0       57         0.57
# 3  (47.714, 55.143]    14      0.14       14.0       71         0.71
# 6  (55.143, 62.571]    11      0.11       11.0       82         0.82
# 0    (62.571, 70.0]    18      0.18       18.0      100         1.00
#
#    Frec Porc Ac
# 2          15.0
# 5          28.0
# 4          42.0
# 1          57.0
# 3          71.0
# 6          82.0
# 0         100.0

# %%
import matplotlib.pyplot as plt

plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion matplpotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion matplpotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
