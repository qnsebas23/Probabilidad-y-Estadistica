# %% [markdown]
# <a href="https://colab.research.google.com/github/qnsebas23/Probabilidad-y-Estadistica/blob/main/unidad1/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Probabilidad y estadistica**
#
# ## Unidad 1
#
# ### *Practica 4. Diagrama de cajas y bigotes.*
#
# ## Facilitador: *Dr. José Gabriel Rodríguez Rivas*
#
# ### ALumno: Sebastian Quiñones Nevarez

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [54.96, 50.56, 69.63, 65.23, 95.59, 72.24, 61.88, 71.64, 84.36, 60.7, 55.3, 99.54, 91.19, 61.75, 66.42, 59.95, 61.06, 84.49, 51.87, 65.97, 67.06, 72.22, 59.94, 50.56, 77.25, 87.81, 54.16, 53.02, 82.2, 89.91, 94.25, 72.67, 70.25, 99.75, 53.26, 55.67, 59.92, 75.65, 91.81, 75.72, 70.85, 80.43, 65.3, 98.18, 76.63, 78.34, 71.49, 54.38, 92.38, 60.99, 68.82, 81.99, 88.37, 84.58, 71.35, 95.04, 52.49, 55.82, 85.04, 94.88, 73.54, 59.44, 54.34, 80.75, 82.45, 89.96, 57.28, 83.15, 93.42, 92.34, 95.08, 51.36, 90.12, 77.02, 84.07, 65.51, 89.77, 60.66, 70.7, 93.25, 61.4, 53.26, 88.13, 82.56, 69.53, 74.39, 69.03, 57.64, 65.43, 93.78, 89.09, 71.47, 74.63, 59.87, 84.95, 76.7, 77.04, 84.84, 81.22, 80.72]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(70,100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [75.53, 95.63, 85.79, 99.33, 96.08, 88.71, 76.07, 96.76, 86.19, 75.22, 97.85, 73.6, 76.85, 93.74, 77.05, 99.81, 80.85, 85.95, 94.89, 99.71, 78.23, 79.85, 91.31, 74.97, 98.9, 90.3, 85.86, 84.63, 99.41, 87.07, 87.1, 74.99, 83.1, 80.33, 84.12, 81.43, 94.13, 91.38, 90.64, 73.67, 76.18, 98.96, 85.83, 96.67, 90.7, 94.16, 79.99, 71.11, 86.14, 87.01, 77.45, 80.24, 81.7, 74.4, 92.78, 78.84, 96.64, 73.42, 77.51, 73.78, 88.36, 70.61, 95.25, 96.26, 76.99, 98.17, 79.7, 77.01, 98.57, 77.55, 72.29, 98.96, 77.04, 76.48, 74.17, 96.62, 73.09, 70.77, 82.05, 87.12, 86.25, 98.75, 75.2, 75.07, 95.38, 77.25, 88.1, 90.68, 70.2, 95.26, 91.95, 86.42, 93.85, 84.13, 97.87, 97.48, 70.95, 79.8, 88.64, 98.54]

# %% [markdown]
# ##Diagrama de Cajas y bigotes

# %%
plt.boxplot(fabrica1)
plt.ylabel('Edades')
plt.title('Produccion fabrica 1')
plt.show()

# %%
plt.boxplot(fabrica2)
plt.ylabel('Edades')
plt.title('Produccion fabrica 2')
plt.show()

# %% [markdown]
# ##Comparamos la produccion de la fabrica 1 y 2 en un subplot

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True, # vertical box alignment
                     patch_artist=True)
ax1.set_title('Produccion fabrica 1')

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, # vertical box alignment
                     patch_artist=True)
ax2.set_title('Produccion fabrica 2')
plt.show()

# %%
fabrica1.append(150)
print(fabrica1)
# Out:
# [54.96, 50.56, 69.63, 65.23, 95.59, 72.24, 61.88, 71.64, 84.36, 60.7, 55.3, 99.54, 91.19, 61.75, 66.42, 59.95, 61.06, 84.49, 51.87, 65.97, 67.06, 72.22, 59.94, 50.56, 77.25, 87.81, 54.16, 53.02, 82.2, 89.91, 94.25, 72.67, 70.25, 99.75, 53.26, 55.67, 59.92, 75.65, 91.81, 75.72, 70.85, 80.43, 65.3, 98.18, 76.63, 78.34, 71.49, 54.38, 92.38, 60.99, 68.82, 81.99, 88.37, 84.58, 71.35, 95.04, 52.49, 55.82, 85.04, 94.88, 73.54, 59.44, 54.34, 80.75, 82.45, 89.96, 57.28, 83.15, 93.42, 92.34, 95.08, 51.36, 90.12, 77.02, 84.07, 65.51, 89.77, 60.66, 70.7, 93.25, 61.4, 53.26, 88.13, 82.56, 69.53, 74.39, 69.03, 57.64, 65.43, 93.78, 89.09, 71.47, 74.63, 59.87, 84.95, 76.7, 77.04, 84.84, 81.22, 80.72, 150]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True, # vertical box alignment
                     patch_artist=True)
ax1.set_title('Produccion fabrica 1')

bplot2 = ax2.boxplot(fabrica2,
                     vert=True, # vertical box alignment
                     patch_artist=True)
ax2.set_title('Produccion fabrica 2')
plt.show()
